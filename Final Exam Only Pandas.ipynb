# %% [markdown]
# <div>
#     <img src="emlyon.png" style="height:60px; float:left; padding-right:10px; margin-top:5px" />
#     <span>
#         <h1 style="padding-bottom:5px;"> Python BootCamp </h1>
#         <a href="https://masters.em-lyon.com/en/msc-in-digital-marketing-data-science">[Emlyon]</a> MSc in Digital Marketing & Data Science (DMDS) <br/>
#          December 2022, Paris | © Saeed VARASTEH [RP] | Lucas VILLAIN
#     </span>
# </div>

# %% [markdown]
# <div class="alert-info" style="border-bottom: solid 1px lightgray; background-color:#d3dbd3; text-align:left">
#     <span style="font-weight:bold; color:#476b47">
#         <h4 style="padding:15px;"> FINAL EXAM </h4>
#     </span>
# </div>
# <div style="text-align:right">Dec 16th, 2022</div>

# %% [markdown]
# <hr style="color:gray;"/>
#
# __Your Name: Marco ARADILLOS__  Double-click here and write your name.
#
# <hr style="color:gray;"/>

# %% [markdown]
# <h5 style="color:red">Notes:</h5>
#
# <ul>
#     <li>Do not forget to enter <b>your name</b> above.</li>
#     <li>Do not forget to <b>comment your codes</b> as much as you can.</li>
#     <li>Do not try to search directly for the answers online. However, if you do, which is not recommended, comment on the code and explain the solution and <b>cite the url</b> that you picked the code from.</li>
#     <li>Do not share your codes.</li>
# </ul>
#
# <h5 style="color:gray">Good Luck!</h5>
#
# ---

# %% [markdown]
# ### Question 06 - Diabetes Dataset (30 points)
#
# ---

# %% [markdown]
# You are given a file named __diabetes.csv__.
#
# This data has been used to predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset.
#
# What is diabetes? Acccording to NIH, diabetes is a disease that occurs when your blood glucose, also called blood sugar, is too high.
#
# Columns description:
#
# - __Pregnancies:__ The number of pregnancies the patient has had.
# - __Glucose:__ Plasma glucose concentration.
# - __BloodPressure:__ Diastolic blood pressure (mm Hg)
# - __SkinThickness:__ Triceps skin fold thickness (mm)
# - __Insulin:__ 2-Hour serum insulin (mu U/ml)
# - __BMI:__ Body mass index, (weight in kg / (height in m)^2)
# - __DiabetesPedigreeFunction:__ Diabetes pedigree function
# - __Age:__ Patient's age (years)
# - __Outcome:__ Whether or not the patient has diabetes (1: yes, 0: no)
#
# This dataset contains only information of the females patients of at least 21 years old.

# %% [markdown]
# 1- Read the file "diabetes.csv" into a Pandas `DataFrame`.

# %%
# your code
import pandas as pd
import numpy as np
df = pd.read_csv('diabetes.csv', index_col=0)

df=df.reset_index()

# showing every column for better initial analysis of the DF
pd.set_option('display.max_columns', None) 
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# 2- Display a summary of the basic information about the data.

# %%
# your code
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# 3- Print out the first 5 rows of the data.

# %%
# your code
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 4- Rename "DiabetesPedigreeFunction" column to "DPF"

# %%
# your code
df = df.rename(columns = {'DiabetesPedigreeFunction':'DPF'})
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI    DPF  \
# 0              6      148             72             35        0  33.6  0.627
# 1              1       85             66             29        0  26.6  0.351
# 2              8      183             64              0        0  23.3  0.672
# 3              1       89             66             23       94  28.1  0.167
# 4              0      137             40             35      168  43.1  2.288
# ..           ...      ...            ...            ...      ...   ...    ...
# 763           10      101             76             48      180  32.9  0.171
# 764            2      122             70             27        0  36.8  0.340
# 765            5      121             72             23      112  26.2  0.245
# 766            1      126             60              0        0  30.1  0.349
# 767            1       93             70             31        0  30.4  0.315
#
#      Age  Outcome
# ...

# %% [markdown]
# 5- What are the number of non-diabetics and diabetic patients in the dataset?

# %%
# your code
#using group by to to count how many diabetics there are
dibetic_count = df.groupby('Outcome')['Pregnancies'].count()
diabetic_count_df = pd.DataFrame(dibetic_count)
diabetic_count_df.rename(columns={'Pregnancies':'patient count'}, inplace=True)
diabetic_count_df
# Out:
#          patient count
# Outcome
# 0                  500
# 1                  268

# %% [markdown]
# 6- Plot BMI distribution histogram:

# %%
# your code
import matplotlib.pyplot as plt

df = pd.read_csv('diabetes.csv')

# selecting BMI
bmi = df['BMI']

plt.hist(bmi)
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 7- How many zero values do we have in the BMI column?

# %%
# your code

# using the method value conts to find all the zeros in the BMI column
count_zero = df['BMI'].value_counts()[0]

print(f'Number of zero values in the BMI column: {count_zero}')
# Out:
# Number of zero values in the BMI column: 11

# %% [markdown]
# 8- Replace all the zero values in the BMI column with the median of this column.

# %%
# your code
BMI_median = df['BMI'].median()

# changing the zeros in the BMI column to the median
df['BMI'] = df['BMI'].replace(0, BMI_median)

df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# 9- Replace all the zero values in the SkinThickness column with the mean of this column.

# %%
# your code
ST_median = df['SkinThickness'].median()

# changing the zeros in the SkinThickness column to the median
df['SkinThickness'] = df['SkinThickness'].replace(0, ST_median)

df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64             23        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             23        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# 10- Check BMI distribution histogram one more time:

# %%
# your code
bmi = df['BMI']

plt.hist(bmi)
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 11- Plot the ages distribution histogram:

# %%
ages = df['Age']

plt.hist(ages)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64             23        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             23        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# 12- Plot BMI versus SkinThickness values in the scatters plot.

# %%
# your code

df_plot = df[['BMI', 'SkinThickness']]

# Plotting the BMI against Skin Thickness
df_plot.plot(x='BMI', y='SkinThickness', kind='scatter')

# Adding titles and axis labels
plt.title('BMI vs Skin Thickness')
plt.xlabel('BMI')
plt.ylabel('Skin Thickness')

plt.show()

# %% [markdown]
# 13- What can you tell about this plot? Is there a relationship between BMI and SkinThickness values?

# %%
# explain in words
print( "There is a direct positive correlation between the two. Genrally, the lower the BMI, the lower the skin thickness is, and the higher the BMI, the skin thickness goes up as well")
# Out:
# There is a direct positive correlation between the two. Genrally, the lower the BMI, the lower the skin thickness is, and the higher the BMI, the skin thickness goes up as well

# %% [markdown]
# 14- Compare the Glucose distributions for diabetic and non-diabetic patients.

# %%
# your code
# using groupby method, utilizing the outcome column
grouped_df = df.groupby('Outcome')

# Using a histogram to compare the two
grouped_df['Glucose'].plot.hist(alpha=0.8)

plt.legend(['Non-Diabetic', 'Diabetic'])

# labeling the axis and adding a title
plt.title('Glucose: Diabetic VS Non-Diabetic Patients')
plt.xlabel('Glucose')
plt.ylabel('Patient Count')

plt.show()

# %%
# getting another perspective, comparing means between diabetics and non diabetics using pivot_table
table = df.pivot_table(index='Outcome', values='Glucose', aggfunc='mean')
print(table)
# Out:
#             Glucose
# Outcome
# 0        109.980000
# 1        141.257463

# %% [markdown]
# 15- What is the percentage of diabetic patients over 40?

# %%
# your code

diabetic_over_40 = df[(df['Outcome'] == 1) & (df['Age'] > 40)]

# Counting the rows
num_diabetic_over_40 = diabetic_over_40.count()

total_rows = len(df)

# Selecting the "Age" column from num_diabetic_over_40 Series
num_diabetic_over_40_age = num_diabetic_over_40['Age']

# checking the percentage of patients over 40 that are diabetics
percentage = (num_diabetic_over_40_age / total_rows) * 100

# Print the result
print(f'{percentage:.2f}% of patients are diabetic and over 40.')

#Sources from stackoverflow
# Out:
# 13.28% of patients are diabetic and over 40.

# %% [markdown]
# 16- Create a new boolean column and name it __treatment__. Set its values to `True` if the __insulin__ level is greater than 79.8 and `False` otherwise.

# %%
# your code

# Create a new boolean column and set its values using a lambda function
df['Treatment'] = df['Insulin'].apply(lambda x: x > 79.8)

# Print the resulting DataFrame
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64             23        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             23        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Treatment
# 0                       0.627   50        1      False
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64             23        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             23        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Treatment
# 0                       0.627   50        1      False
# ...

# %% [markdown]
# 17- Create a frequency table (cross table) between the __treatment__ column and the Outcome column:

# %%
# your code

ct_Treatment = pd.crosstab(index=df['Treatment'], columns=df['Outcome'])
print(ct_Treatment)
# Out:
# Outcome      0    1
# Treatment
# False      332  147
# True       168  121

# %%
false0 = 332
true0 = 168
false1 = 147
true1 = 121

x = (121/268)
x
# Out:
# 0.45149253731343286

# %% [markdown]
# 18- Based on the above frequency table, What can you tell about the treatment effect (i.e. applying insulin) on the Outcome (diagnosis as a diabetic patient)

# %%
# explain in words
print("Total non diabetics are 500, total diabetics are 268. 33% of non diabetics got the treatment while 67% didnt. While for diabetics, 45% of them got the treatment. Meaning the treatment is more for the diabetic patients.")
# Out:
# Total non diabetics are 500, total diabetics are 268. 33% of non diabetics got the treatment while 67% didnt. While for diabetics, 45% of them got the treatment. Meaning the treatment is more for the diabetic patients.

# %% [markdown]
# 19- Compute the percentage difference in the outcome of the patients who got treated and the patients who  did not.

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64             23        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             23        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Treatment
# 0                       0.627   50        1      False
# ...

# %% [markdown]
# ---
